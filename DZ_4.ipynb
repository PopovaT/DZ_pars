# %% [markdown]
# <a href="https://colab.research.google.com/github/PopovaT/DZ_pars/blob/lesson_4/DZ_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pprint import pprint
from bs4 import BeautifulSoup as bs
import requests
from time import sleep

# %% [markdown]
# ## Парсинг

# %%
USER_AGENT = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'

URL_FIRST_PAGE_HH = 'https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20'

# %%
headers = {
    'User-Agent': USER_AGENT,
}

# %%
def parse_hh(url_page, headers, result=[], index_page=1):
    response = requests.get(url_page, headers=headers)
    if response.status_code != 200:
      print('Парсинг завершен')
      return result
    else:
      print('Cтраница №%d, ссылка: %s'%(index_page, response.url))

    dom = bs(response.content, 'html.parser')
    vacancies = dom.find_all('div', {'class': 'vacancy-serp-item__layout'})
    for vacancy in vacancies:
      result.append(parse_vacancy_hh(vacancy))

    link_next_page = dom.find('a', {'data-qa': 'pager-next'})
    if link_next_page:
      link_next_page =  'https://spb.hh.ru' + link_next_page['href']
    else:
      print('Парсинг завершен')
      return result

    result = parse_hh(link_next_page, headers, result, index_page+1)   
    return result
     
def parse_vacancy_hh(dom_vacancy):
  sleep(0.1)
  vacancy_name = dom_vacancy.find('a').text

  vacancy_salary = dom_vacancy.find('span', {'class', 'bloko-header-section-3'})
  if vacancy_salary:
    vacancy_salary = vacancy_salary.text
    min_salary, max_salary, currency_salary = clean_salary(vacancy_salary)
  else:
    min_salary, max_salary, currency_salary = None, None, None

  vacancy_link = dom_vacancy.find('a')['href']
  
  return {
      'vacancy_name': vacancy_name,
      'vacancy_salary': vacancy_salary,
      'min_salary': min_salary,
      'max_salary': max_salary,
      'currency_salary': currency_salary,
      'vacancy_link': vacancy_link,
      'vacancy_source': 'hh.ru',
  }

def clean_salary(vacancy_salary_text, min_salary=None, max_salary=None, currency_salary=None):
  list_salary = vacancy_salary_text.replace('\u202f', '').split()
  for i in range(len(list_salary) - 1):
    if list_salary[i] == 'от':
      min_salary = int(list_salary[i + 1])
    elif list_salary[i] == 'до':
      max_salary = int(list_salary[i + 1])
    elif list_salary[i] == '–':
      min_salary = int(list_salary[i - 1])
      max_salary = int(list_salary[i + 1])
  currency_salary = list_salary[-1]

  return min_salary, max_salary, currency_salary

# %%
result = parse_hh(URL_FIRST_PAGE_HH, headers)
# Out:
# Cтраница №1, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20
# Cтраница №2, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20&page=1&hhtmFrom=vacancy_search_list
# Cтраница №3, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20&page=2&hhtmFrom=vacancy_search_list
# Cтраница №4, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20&page=3&hhtmFrom=vacancy_search_list
# Cтраница №5, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20&page=4&hhtmFrom=vacancy_search_list
# Cтраница №6, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20&page=5&hhtmFrom=vacancy_search_list
# Cтраница №7, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20&page=6&hhtmFrom=vacancy_search_list
# Cтраница №8, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20&page=7&hhtmFrom=vacancy_search_list
# Cтраница №9, ссылка: https://spb.hh.ru/search/vacancy?area=88&search_field=name&search_field=company_name&search_field=description&text=python&no_magic=true&L_save_area=true&items_on_page=20&page=8&hhtmFrom=vacancy_search_list
# Парсинг завершен

# %%
len(result)
# Out:
# 168

# %% [markdown]
# ## Установка `mongo` сервер и клиент

# %%
# !apt install mongodb > log
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
# !service mongodb start
# Out:
#  * Starting database mongodb
#    ...done.

# %%
# !pip install pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pymongo in /usr/local/lib/python3.8/dist-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from pymongo) (2.3.0)

# %% [markdown]
# ## Запись данных в базу

# %%
from pymongo import MongoClient

# %%
client = MongoClient()

# %%
db = client.vacancies_python_hh

# %%
collection_vacancies_hh_ru = db.hh_ru

# %%
def cheak_and_save_vacancies_in_db(vacancies):
  for vacancy in vacancies:
    if not len(list(collection_vacancies_hh_ru.find({'vacancy_link': vacancy['vacancy_link']}))):
      collection_vacancies_hh_ru.insert_one(vacancy)

# %%
cheak_and_save_vacancies_in_db(result)

# %%
result_find = list(collection_vacancies_hh_ru.find())

# %%
len(result_find)
# Out:
# 154

# %%
result_find
# Out:
# [{'_id': ObjectId('63f894f36e459a406074ad91'),
#   'vacancy_name': 'Middle Python developer (Казань)',
#   'vacancy_salary': 'от 160\u202f000 руб.',
#   'min_salary': 160000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76115939?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ad92'),
#   'vacancy_name': 'Разработчик Python',
#   'vacancy_salary': 'от 120\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76076341?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ad93'),
#   'vacancy_name': 'Lead Python developer',
#   'vacancy_salary': 'до 500\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 500000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77337810?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ad94'),
#   'vacancy_name': 'Junior/Middle Backend-разработчик на Ruby',
#   'vacancy_salary': '110\u202f000 – 150\u202f000 руб.',
#   'min_salary': 110000,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76964796?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ad95'),
#   'vacancy_name': 'Python разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75951525?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ad96'),
#   'vacancy_name': 'Python Developer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76843829?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ad97'),
#   'vacancy_name': 'Python-разработчик (middle)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77289628?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ad98'),
#   'vacancy_name': 'Преподаватель Python',
#   'vacancy_salary': 'от 125\u202f000 руб.',
#   'min_salary': 125000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77083921?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ad99'),
#   'vacancy_name': 'Python разработчик',
#   'vacancy_salary': 'от 350\u202f000 руб.',
#   'min_salary': 350000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76929580?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ad9a'),
#   'vacancy_name': 'Python senior developer (разработчик)',
#   'vacancy_salary': 'от 250\u202f000 руб.',
#   'min_salary': 250000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76840136?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ad9b'),
#   'vacancy_name': 'Team Lead Python',
#   'vacancy_salary': 'от 400\u202f000 руб.',
#   'min_salary': 400000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76930290?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ad9c'),
#   'vacancy_name': 'Python backend-разработчик в команду Data Science',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77050357?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ad9d'),
#   'vacancy_name': 'Системный администратор Linux (Казань)',
#   'vacancy_salary': 'от 180\u202f000 руб.',
#   'min_salary': 180000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76115945?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ad9e'),
#   'vacancy_name': 'Системный аналитик (systems analyst)',
#   'vacancy_salary': 'от 120\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77145441?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ad9f'),
#   'vacancy_name': 'Ведущий инженер-программист (python, С/C++)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76919357?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ada0'),
#   'vacancy_name': 'Программист Python',
#   'vacancy_salary': '110\u202f000 – 130\u202f000 руб.',
#   'min_salary': 110000,
#   'max_salary': 130000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76468048?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ada1'),
#   'vacancy_name': 'Инженер - исследователь (Data Science)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77129293?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ada2'),
#   'vacancy_name': 'Python-разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76408321?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ada3'),
#   'vacancy_name': 'Ведущий Python-developer',
#   'vacancy_salary': '240\u202f000 – 300\u202f000 руб.',
#   'min_salary': 240000,
#   'max_salary': 300000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76726067?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ada4'),
#   'vacancy_name': 'Middle Python developer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76783377?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ada5'),
#   'vacancy_name': 'Middle программист Python (платежные сервисы)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75552925?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ada6'),
#   'vacancy_name': 'Python Developer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76649090?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ada7'),
#   'vacancy_name': 'Python Developer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76597591?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ada8'),
#   'vacancy_name': 'Автор работ по программированию Python',
#   'vacancy_salary': 'до 90\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 90000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76611770?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ada9'),
#   'vacancy_name': 'ML Engineer',
#   'vacancy_salary': '140\u202f000 – 180\u202f000 руб.',
#   'min_salary': 140000,
#   'max_salary': 180000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76581205?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adaa'),
#   'vacancy_name': 'Python разработчик (Middle/Senior)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75627492?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adab'),
#   'vacancy_name': 'Разработчик в тестировании/SDET (Python)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76748575?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adac'),
#   'vacancy_name': 'Ведущий разработчик Python',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75936654?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adad'),
#   'vacancy_name': 'Преподаватель компьютерных курсов для взрослых тестировка, web-дизайн, С++ ,С#, Python, JavaScript,',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76398236?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adae'),
#   'vacancy_name': 'QA Automation Python',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77321013?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adaf'),
#   'vacancy_name': 'Senior Python разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76287301?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adb0'),
#   'vacancy_name': 'Senior/Lead Python-разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76921593?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adb1'),
#   'vacancy_name': 'Data Engineer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76327290?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adb2'),
#   'vacancy_name': 'Data-инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76888795?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adb3'),
#   'vacancy_name': 'QA automation engineer (Python)',
#   'vacancy_salary': 'до 250\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 250000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76904584?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adb4'),
#   'vacancy_name': 'Middle/Senior Python-разработчик в команду Добычи данных',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/66066365?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adb5'),
#   'vacancy_name': 'Программист Python',
#   'vacancy_salary': '25\u202f000 – 90\u202f000 руб.',
#   'min_salary': 25000,
#   'max_salary': 90000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76413349?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adb6'),
#   'vacancy_name': 'Программист Python',
#   'vacancy_salary': 'от 150\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76661687?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adb7'),
#   'vacancy_name': 'Программист',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76974239?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adb8'),
#   'vacancy_name': 'Разработчик Asyncio, AioHttp уровня Middle',
#   'vacancy_salary': '130\u202f000 – 190\u202f000 руб.',
#   'min_salary': 130000,
#   'max_salary': 190000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77282299?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adb9'),
#   'vacancy_name': 'Разработчик SCADA-систем (C#, Python)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77277225?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adba'),
#   'vacancy_name': 'QA automation engineer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77328098?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adbb'),
#   'vacancy_name': 'Технический писатель со знанием IT',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76569401?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adbc'),
#   'vacancy_name': 'Инженер-программист в группу техподдержки продукта Naumen Service Desk',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77145210?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adbd'),
#   'vacancy_name': 'DevOps инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77296876?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adbe'),
#   'vacancy_name': 'Trading Platform Reliability Engineer',
#   'vacancy_salary': 'от 1\u202f000 USD',
#   'min_salary': 1000,
#   'max_salary': None,
#   'currency_salary': 'USD',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76095405?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adbf'),
#   'vacancy_name': 'Технический писатель со знанием IT',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76986486?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adc0'),
#   'vacancy_name': 'Senior Software Design Engineer in Test (Python)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77207602?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adc1'),
#   'vacancy_name': 'Инженер Linux',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/54220301?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adc2'),
#   'vacancy_name': 'Специалист по информационной безопасности (ФинТех)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77091039?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adc3'),
#   'vacancy_name': 'Системный администратор Linux ( Middle, Senior )',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76782816?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adc4'),
#   'vacancy_name': 'Devops Engineer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/74267896?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adc5'),
#   'vacancy_name': 'Специалист службы поддержки с техническими знаниями (TOOLS)',
#   'vacancy_salary': '15\u202f000 – 39\u202f000 руб.',
#   'min_salary': 15000,
#   'max_salary': 39000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/73595107?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adc6'),
#   'vacancy_name': 'Специалист службы поддержки с техническими знаниями (Контест)',
#   'vacancy_salary': '15\u202f000 – 39\u202f000 руб.',
#   'min_salary': 15000,
#   'max_salary': 39000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/48224443?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adc7'),
#   'vacancy_name': 'Специалист по тестированию на проникновение (pentest)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76272121?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adc8'),
#   'vacancy_name': 'Senior fullstack разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77088713?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adc9'),
#   'vacancy_name': 'Team leader Группы разработки',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77321225?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adca'),
#   'vacancy_name': 'Аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77287075?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adcb'),
#   'vacancy_name': 'Аналитик бизнес процессов',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76279241?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adcc'),
#   'vacancy_name': 'Инженер данных (качество сервисов,SLA)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/70972873?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adcd'),
#   'vacancy_name': 'Системный администратор 2 линия',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69369250?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adce'),
#   'vacancy_name': 'Middle/Senior QA Mobile (Manual) / Тестировщик ПО',
#   'vacancy_salary': 'от 150\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77224947?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adcf'),
#   'vacancy_name': 'Руководитель направления HR аналитики',
#   'vacancy_salary': 'от 150\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76145094?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074add0'),
#   'vacancy_name': 'Инженер по сопровождению КХД',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77217236?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074add1'),
#   'vacancy_name': 'DevOps инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76762935?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074add2'),
#   'vacancy_name': 'Team lead',
#   'vacancy_salary': 'от 190\u202f000 руб.',
#   'min_salary': 190000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76549882?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074add3'),
#   'vacancy_name': 'Бизнес-аналитик (Операционный маркетинг)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/71039387?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074add4'),
#   'vacancy_name': 'Ведущий специалист отдела виртуализации',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77130858?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074add5'),
#   'vacancy_name': 'Аналитик по сетевой безопасности',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75936842?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074add6'),
#   'vacancy_name': 'Эксперт в Команду "Чат-бот"',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76911066?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074add7'),
#   'vacancy_name': 'Системный архитектор (информационная безопасность)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76956883?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074add8'),
#   'vacancy_name': 'Инженер DevOps',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77155085?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074add9'),
#   'vacancy_name': 'DevOps инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/73776674?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adda'),
#   'vacancy_name': 'DevOps инженер (Junior)',
#   'vacancy_salary': '80\u202f000 – 120\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': 120000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76767021?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074addb'),
#   'vacancy_name': 'Бизнес-партнер / BP (промышленное производство)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77176864?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074addc'),
#   'vacancy_name': 'Руководитель группы разработки С++',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76954547?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074addd'),
#   'vacancy_name': 'Руководитель группы разработки С++',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76954494?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adde'),
#   'vacancy_name': 'Внутренний аудитор (крупное промышленное производство)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77176522?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074addf'),
#   'vacancy_name': 'Заведующий сектором пространственных данных',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76794324?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ade0'),
#   'vacancy_name': 'Программист-разработчик систем САУ',
#   'vacancy_salary': 'до 200\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76817912?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ade1'),
#   'vacancy_name': 'DevOps-инженер (Казань)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/66729881?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ade2'),
#   'vacancy_name': 'Руководитель группы разработки (Team Lead)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77224953?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ade3'),
#   'vacancy_name': 'Senior С++ Developer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75713615?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ade4'),
#   'vacancy_name': 'Техлид / Tech Lead BigData',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75747550?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ade5'),
#   'vacancy_name': 'Бизнес-аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/73882541?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ade6'),
#   'vacancy_name': 'Старший аналитик SOC (L2)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76646711?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ade7'),
#   'vacancy_name': 'Data Engineer (BigData)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76539993?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ade8'),
#   'vacancy_name': 'Аналитик L2 (SOC)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/45403221?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074ade9'),
#   'vacancy_name': 'Преподаватель робототехники',
#   'vacancy_salary': '60\u202f000 – 100\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': 100000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76403858?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adea'),
#   'vacancy_name': 'Руководитель группы сетевых инженеров',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/74404753?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adeb'),
#   'vacancy_name': 'Инженер-программист',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/72754447?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adec'),
#   'vacancy_name': 'PHP-разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/74123858?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074aded'),
#   'vacancy_name': 'HR Аналитик',
#   'vacancy_salary': 'от 70\u202f000 руб.',
#   'min_salary': 70000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77111054?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adee'),
#   'vacancy_name': 'DevOps-инженер (middle/senior, kubernetes)',
#   'vacancy_salary': '100\u202f000 – 150\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76655413?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adef'),
#   'vacancy_name': 'Аналитик данных',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77079684?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adf0'),
#   'vacancy_name': 'Руководитель отдела испытаний',
#   'vacancy_salary': '90\u202f000 – 150\u202f000 руб.',
#   'min_salary': 90000,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76451229?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f36e459a406074adf1'),
#   'vacancy_name': 'QA engineer (auto + manual)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77005657?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074adf2'),
#   'vacancy_name': 'Старший системный администратор Linux',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76974868?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074adf3'),
#   'vacancy_name': 'Аналитик по информационной безопасности (Vulnerability Management)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/72191481?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074adf4'),
#   'vacancy_name': 'Специалист по тестированию / QA engineer (Junior)',
#   'vacancy_salary': 'от 40\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76968641?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074adf5'),
#   'vacancy_name': 'Маркетолог',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76998906?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074adf6'),
#   'vacancy_name': 'Data Analyst',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/71833309?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074adf7'),
#   'vacancy_name': 'ML Engineer (Computer Vision)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76558811?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074adf8'),
#   'vacancy_name': 'ML Engineer (Natural Language Processing)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76561183?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074adf9'),
#   'vacancy_name': 'Аналитик данных',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/72306121?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074adfa'),
#   'vacancy_name': 'ETL developer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76536219?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074adfb'),
#   'vacancy_name': 'QA Manual middle',
#   'vacancy_salary': 'до 150\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76940164?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074adfc'),
#   'vacancy_name': 'Инженер по нагрузочному тестированию',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76919325?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074adfd'),
#   'vacancy_name': 'Backend разработчик С++ в команду Транспорта',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/72747031?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074adfe'),
#   'vacancy_name': 'Application security specialist',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76539544?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074adff'),
#   'vacancy_name': 'Разработчик ETL',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76888773?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae00'),
#   'vacancy_name': 'Менеджер проекта',
#   'vacancy_salary': '150\u202f000 – 320\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': 320000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76910722?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae01'),
#   'vacancy_name': 'DevOps инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75684741?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae02'),
#   'vacancy_name': 'Программист-тестировщик (отдел автотестирования)',
#   'vacancy_salary': '46\u202f000 – 92\u202f000 руб.',
#   'min_salary': 46000,
#   'max_salary': 92000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75786851?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae03'),
#   'vacancy_name': 'Системный администратор серверов Linux (удаленно)',
#   'vacancy_salary': '230\u202f000 – 230\u202f000 руб.',
#   'min_salary': 230000,
#   'max_salary': 230000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76505079?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae04'),
#   'vacancy_name': 'Программист роботов',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76793294?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae05'),
#   'vacancy_name': 'Разработчик в тестировании / SDET (Java)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76771245?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae06'),
#   'vacancy_name': 'Системный аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75558913?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae07'),
#   'vacancy_name': 'Разработчик Java',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76783042?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae08'),
#   'vacancy_name': 'Data engineer (middle)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76715247?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae09'),
#   'vacancy_name': 'Golang разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76725570?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae0a'),
#   'vacancy_name': 'Аналитик портфеля розничных кредитов',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76710627?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae0b'),
#   'vacancy_name': 'Системный администратор (инженер по внедрению)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76720819?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae0c'),
#   'vacancy_name': 'Specialist DevOps',
#   'vacancy_salary': 'до 280\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 280000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69142942?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae0d'),
#   'vacancy_name': 'Специалист группы сопровождения биллинга',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76733886?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae0e'),
#   'vacancy_name': 'Автор работ по программированию / программист',
#   'vacancy_salary': 'до 90\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 90000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76670173?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae0f'),
#   'vacancy_name': 'Системный администратор Linux',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/74406735?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae10'),
#   'vacancy_name': 'Системный аналитик',
#   'vacancy_salary': '100\u202f000 – 200\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76652169?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae11'),
#   'vacancy_name': 'DevOps инженер (Брокерский бизнес)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76642389?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae12'),
#   'vacancy_name': 'DevOps engineer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/74370556?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae13'),
#   'vacancy_name': 'Системный аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/74371352?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae14'),
#   'vacancy_name': 'QA automation engineer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/74370491?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae15'),
#   'vacancy_name': 'Разработчик С++ в команду 3D Карта',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76073156?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae16'),
#   'vacancy_name': 'DevOps инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76503776?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae17'),
#   'vacancy_name': 'QA automation Pytest/Selenium WebDriver',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76507494?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae18'),
#   'vacancy_name': 'Системный администратор Linux',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/73081919?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae19'),
#   'vacancy_name': 'Инженер по безопасной разработке (AppSec инженер)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/70738268?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae1a'),
#   'vacancy_name': 'Data Engineer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76442309?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae1b'),
#   'vacancy_name': 'Инженер по внедрению и техподдержке телекоммуникационного биллинга',
#   'vacancy_salary': 'до 170\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 170000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76459460?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae1c'),
#   'vacancy_name': 'Преподаватель-практик лабораторного химического анализа',
#   'vacancy_salary': 'до 125\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 125000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76498193?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae1d'),
#   'vacancy_name': 'Инженер-программист (BI, Qlik Sense)',
#   'vacancy_salary': '40\u202f000 – 60\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': 60000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76375489?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae1e'),
#   'vacancy_name': 'Системный администратор Linux',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76411484?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae1f'),
#   'vacancy_name': 'DevOps инженер (Linux)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75777798?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae20'),
#   'vacancy_name': 'Программист 1С (стажер)',
#   'vacancy_salary': '35\u202f000 – 40\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': 40000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76435256?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae21'),
#   'vacancy_name': 'QA automation (R&D)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/74246182?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae22'),
#   'vacancy_name': 'Консультант 1С',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/74378411?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae23'),
#   'vacancy_name': 'Руководитель направления безопасности кода',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/74273857?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae24'),
#   'vacancy_name': 'Middle С++ Developer (Cloud)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76339882?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae25'),
#   'vacancy_name': 'BI analyst',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76536041?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae26'),
#   'vacancy_name': 'DWH разработчик / DWH инженер / Data Engineer',
#   'vacancy_salary': 'от 110\u202f000 руб.',
#   'min_salary': 110000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76291842?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae27'),
#   'vacancy_name': 'Продуктовый аналитик',
#   'vacancy_salary': 'от 80\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76283804?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae28'),
#   'vacancy_name': 'Системный администратор',
#   'vacancy_salary': '44\u202f000 – 75\u202f000 руб.',
#   'min_salary': 44000,
#   'max_salary': 75000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76264846?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae29'),
#   'vacancy_name': 'Ведущий QA инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76637802?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'},
#  {'_id': ObjectId('63f894f46e459a406074ae2a'),
#   'vacancy_name': 'QA mobile / Инженер по тестированию (manual/auto) в Тинькофф Мобильный Банк',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76266218?from=vacancy_search_list&query=python',
#   'vacancy_source': 'hh.ru'}]
