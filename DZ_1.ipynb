# %% [markdown]
# <a href="https://colab.research.google.com/github/PopovaT/DZ_pars/blob/lesson_1/DZ_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ЗАДАНИЕ 1**

# %% [markdown]
# Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
# устанавливаем requests
# !pip install requests

# %%
# импортируем библиотеки
import requests
import json

# %%
# создаем запрос
url = 'https://api.github.com'
user = 'PopovaT'
reg = requests.get(f'{url}/users/{user}/repos')

# %%
# Записываем
with open('data.json', 'w') as f:
  json.dump(reg.json(), f)
for i in reg.json():
   print(i['name'])
# Out:
# DZ_pars
# My_DZ
# PopovaTatyana

# %% [markdown]
# ЗАДАНИЕ 2

# %% [markdown]
# Изучить список открытых API (https://www.programmableweb.com/category/all/apis.
#
# Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.
#
# Если нет желания заморачиваться с поиском, возьмите API вконтакте (https://vk.com/dev/first_guide).
#
# Сделайте запрос, чтобы получить список всех сообществ на которые вы подписаны.

# %%
from pprint import pprint
url = 'http://api.vk.com'

method = 'groups.get'
access_token = 'vk1.a.jWqK5lPJgSa25MWQM5FzAAwwBVoXo7bFjByN2PylGecf51r1n3Yfbm-LvLwkFHcZLMV2bNOIQAeQ4Por7VPFedG9ILc5GQo_cq7AfC11L6D8C3KNCCDO-mHNW0yrJkG-XYHh9m6D5zddlCBrkGshUfJzYG7vG47t6-5WBxyYDzNfSLnfxTAtgrCegmPsNqoE-vRtpjTno-4xPUmVcl0YcQ'
V = '5.204'

params = {
    'user_id': '88054958',
    'extended': '1',
};

response = requests.get(f'{url}/method/{method}?{params}&access_token={access_token}&v={V}&extended={extended}')

with open('data_vk.json', 'w') as f:
    json.dump(response.json(), f)


name_list = response.json()['response']['items']
for i in name_list:
    pprint(i['name'])
# Out:
# 'МАУ ДО ДЮСШ Красноуфимск'
# 'Подслушано Красноуфимск'
# 'Женский взгляд'
# 'Женские штучки'
# 'Интересно знать'
# 'В Красноуфимске'
# 'ГКУ "Красноуфимский центр занятости"'
# 'ПриЗнание МАОУ СШ 3'
# 'Звездный ответ'
# 'Прямой репортаж'
# 'Умница, красавица ♥'
# 'Красноуфимск Онлайн КСК66 | ksk66.ru'
# 'Фитнес Повар | Правильное питание'
# 'Комнатные растения - Красноуфимск.'
# 'Красноуфимский филиал ГБПОУ "СОМК"'
# 'Тайны женской красоты'
# 'Лайфхакерша'
# 'Фитнес Кухня'
# 'Татьяна Зайцева'
# 'Fashion - мода и стиль'
# 'О чем говорят девушки'
# 'Потрясающая девушка'
# 'Психология отношений'
# 'Уют в доме - Идеи вашего дома'
# 'Фитнес-студия Sila Voli'
# 'FITNESS спорт мотивация'
# 'Макияж'
# 'Психология'
# 'ProFitnessLife - Стройная и не голодная!'
# 'Уроки моды, стиля и красоты'
# 'Just Fitness | Фитнес Блог'
# 'ЁЛКИ-ИГОЛКИ | питомник растений | Красноуфимск'
# 'Женские Хитрости'
# 'Фитнес кухня'
# 'Литературный кайф'
# 'Здоровое тело'
# 'Женское отделение'
# ...
